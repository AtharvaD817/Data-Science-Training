# %%
import pandas as pd





df[['batsman', 'venue', 'total']] [(df.total>200) & (df.batsman == 'CH Gayle')]
# Out:
#         batsman                                   venue  total
# 26474  CH Gayle                   M Chinnaswamy Stadium    205
# 26475  CH Gayle                   M Chinnaswamy Stadium    205
# 26476  CH Gayle                   M Chinnaswamy Stadium    205
# 26477  CH Gayle                   M Chinnaswamy Stadium    205
# 26480  CH Gayle                   M Chinnaswamy Stadium    205
# ...         ...                                     ...    ...
# 71307  CH Gayle  Saurashtra Cricket Association Stadium    213
# 71308  CH Gayle  Saurashtra Cricket Association Stadium    213
# 71310  CH Gayle  Saurashtra Cricket Association Stadium    213
# 71311  CH Gayle  Saurashtra Cricket Association Stadium    213
# 71312  CH Gayle  Saurashtra Cricket Association Stadium    213
#
# [354 rows x 3 columns]

# %%
df[(df['total'].max()) & (df['venue'] == 'M Chinnaswamy Stadium')]
# Out:
#        mid        date                  venue               bat_team  \
# 0        1  18/04/2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1        1  18/04/2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2        1  18/04/2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3        1  18/04/2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4        1  18/04/2008  M Chinnaswamy Stadium  Kolkata Knight Riders
# ...    ...         ...                    ...                    ...
# 75884  616  19/05/2017  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75885  616  19/05/2017  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75886  616  19/05/2017  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75887  616  19/05/2017  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75888  616  19/05/2017  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                          bowl_team      batsman      bowler  runs  wickets  \
# ...

# %%
df.total == df.total.max()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76009    False
# 76010    False
# 76011    False
# 76012    False
# 76013    False
# Name: total, Length: 76014, dtype: bool

# %%
df[(df.total == df[df.batsman == 'CH Gayle'].total.min()) & (df['batsman'] == 'CH Gayle')]
# Out:
#       mid        date     venue               bat_team        bowl_team  \
# 7113   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7114   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7115   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7116   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7119   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7120   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7121   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7122   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7129   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7130   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7131   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
# 7132   59  19/04/2009  Newlands  Kolkata Knight Riders  Deccan Chargers
#
# ...

# %%
df[(df.total == df.total.min()) & (df['batsman'] == 'CH Gayle')]
# Out:
# Empty DataFrame
# Columns: [mid, date, venue, bat_team, bowl_team, batsman, bowler, runs, wickets, overs, runs_last_5, wickets_last_5, striker, non-striker, total]
# Index: []

# %%
# Out:
# 67
