# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
plt.plot(yield_apples)

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
plt.plot(years, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges'])

# %%
years
# Out:
# range(2000, 2012)

# %%
apples
# Out:
# [0.895,
#  0.91,
#  0.919,
#  0.926,
#  0.929,
#  0.931,
#  0.934,
#  0.936,
#  0.937,
#  0.9375,
#  0.9372,
#  0.939]

# %%
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x')

plt.xlabel('Years')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, apples, marker='x', c='c', ls='-.', lw=1, ms=7, mew=1, mec='navy', alpha=1)
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, mew=1, mec='black', alpha=.5)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, oranges, 'or')
plt.title("Yield of Oranges (tons per hectare)");

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=10);

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species,
                s=100);

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')

plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species',
                s=100,
                data=flowers_df);

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width);

# %%
# Specifying the number of bins
plt.hist(flowers_df.sepal_width, bins=5,density=True);

# %%
sns.displot(flowers_df.sepal_width,kde=True)

# %%
stat = "count"  # or proportion
sns.histplot(flowers_df.sepal_width, stat=stat, cumulative=True, alpha=.6,kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
import numpy as np

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

plt.hist(setosa_df.sepal_width, alpha=0.4, bins=5);
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=5);

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=10, 
         stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
 
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
 
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
 
data = [23, 17, 35, 29, 12, 41]
 
# Creating plot
fig = plt.figure(figsize =(10, 7))

#plt.pie(data, labels = cars)

plt.pie(data, labels = cars,explode = explode)
#plt.legend()
 
# show plot
plt.show()

# %%
#from urllib.request import urlretrieve

# %%
#urlretrieve('https://i.imgur.com/SkPbq.jpg', 'chart.jpg')

# %%
from PIL import Image

# %%
img = Image.open('image1.jpg')

# %%
img_array = np.array(img)

# %%
img_array[0]
# Out:
# array([[ 52, 255,   3],
#        [ 52, 255,   3],
#        [ 52, 255,   3],
#        ...,
#        [ 50, 254,   0],
#        [ 52, 255,   1],
#        [ 52, 255,   1]], dtype=uint8)

# %%
img_array.shape
# Out:
# (266, 474, 3)

# %%
plt.imshow(img);

# %%
plt.grid(False)
plt.title('A data science meme')
plt.axis('off')
plt.imshow(img);

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array[100:325,105:305]);

# %%
tips_df = sns.load_dataset("tips");
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))

# Use the axes for plotting
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].legend(['Apples', 'Oranges']);
axes[0,0].set_title('Crop Yields in Kanto')


# Pass the axes into seaborn
axes[0,1].set_title('Sepal Length vs. Sepal Width')
sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species, 
                s=100, 
                ax=axes[0,1]);

# Use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

axes[1,0].set_title('Pie chart')
axes[1,0].pie(data, labels = cars)
#axes[1,0].pie(data, labels = cars,explode = explode)
plt.legend()


# Pass the axes into seaborn
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

# Plot an image using the axes
axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])
# Out:
# No handles with labels found to put in legend.
# []

# %%
axes
# Out:
# array([[<AxesSubplot:title={'center':'Crop Yields in Kanto'}, xlabel='Year', ylabel='Yield (tons per hectare)'>,
#         <AxesSubplot:title={'center':'Sepal Length vs. Sepal Width'}, xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:title={'center':'Distribution of Sepal Width'}>],
#        [<AxesSubplot:title={'center':'Pie chart'}>,
#         <AxesSubplot:title={'center':'Flight traffic'}, xlabel='year', ylabel='month'>,
#         <AxesSubplot:title={'center':'Data Science Meme'}>]], dtype=object)

# %%
fig
